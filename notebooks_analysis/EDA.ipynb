# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('https://raw.githubusercontent.com/r41ss4/rennes_da/refs/heads/main/data/merged/merged_df.csv')
# Out:
# /var/folders/q5/bwsxp4bx3jvb0n9scz0gsk500000gn/T/ipykernel_3282/3887959642.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('https://raw.githubusercontent.com/r41ss4/rennes_da/refs/heads/main/data/merged/merged_df.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
flight_counts = df.groupby('airline').size().reset_index(name='Flight_Count')
flight_counts
# Out:
#                               airline  Flight_Count
# 0                             AirAsia         16400
# 1                            AirIndia         82635
# 2                            GO_FIRST         23173
# 3                               GoAir           192
# 4                              IndiGo         45173
# 5                         Jet Airways          3806
# 6                   Multiple carriers          1176
# 7   Multiple carriers Premium economy            14
# 8                            SpiceJet          9819
# 9                              Trujet             1
# 10                     Unkown Airline          1169
# 11                            Vistara        128343
# 12            Vistara Premium economy             3

# %%
plt.figure(figsize=(12, 6))
plt.bar(flight_counts['airline'], flight_counts['Flight_Count'], color='skyblue')
plt.xlabel('airline')
plt.ylabel('Flight Count')
plt.title('Number of Flights by Airline')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()  # Adjust layout for readability
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x=df['airline'],y=df['price'],palette='hls')
plt.title('Airlines Vs Price',fontsize=25)
plt.xlabel('Airline', fontsize=15)
plt.ylabel('Price',fontsize=15)
plt.xticks(rotation=45, ha='right',fontsize=15)
plt.show()
# Out:
# /var/folders/q5/bwsxp4bx3jvb0n9scz0gsk500000gn/T/ipykernel_3282/1614437994.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['airline'],y=df['price'],palette='hls')

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='specific_stops',y='price',data=df,palette='hls')
plt.title('Stops Vs Ticket Price',fontsize=10)
plt.xlabel('Stops',fontsize=10)
plt.ylabel('Price',fontsize=10)
plt.show()
# Out:
# /var/folders/q5/bwsxp4bx3jvb0n9scz0gsk500000gn/T/ipykernel_3282/678101113.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='specific_stops',y='price',data=df,palette='hls')

# %%
dep_price_summary = df.groupby('departure_time')['price'].mean().reset_index()
arrival_price_summary = df.groupby('arrival_time')['price'].mean().reset_index()
dep_price_summary
# Out:
#   departure_time         price
# 0      Afternoon  17671.235061
# 1  Early_Morning  20165.994486
# 2        Evening  20699.693667
# 3     Late_Night   9295.299387
# 4        Morning  20855.399844
# 5          Night  23062.146808

# %%
arrival_price_summary
# Out:
#     arrival_time         price
# 0      Afternoon  17892.215399
# 1  Early_Morning  14368.374693
# 2        Evening  22267.020656
# 3     Late_Night  11284.906078
# 4        Morning  21707.990914
# 5          Night  21586.758341

# %%
# How the Ticket Price change based on the Departure Time?
plt.figure(figsize=(6, 4))
sns.barplot(x='departure_time', y='price', data=dep_price_summary, palette='viridis')
plt.title('Average Ticket Price by Departure Time Category',fontsize=9)
plt.xlabel('Departure Time',fontsize=8)
plt.ylabel('Average Price',fontsize=8)
plt.xticks(fontsize=8)
plt.show()
# Out:
# /var/folders/q5/bwsxp4bx3jvb0n9scz0gsk500000gn/T/ipykernel_3282/207071854.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='departure_time', y='price', data=dep_price_summary, palette='viridis')

# %%
# How the Ticket Price change based on the Arrival Time?
plt.figure(figsize=(6, 4))
sns.barplot(x='arrival_time', y='price', data=arrival_price_summary, palette='viridis')
plt.title('Average Ticket Price by Arrival Time Category',fontsize=9)
plt.xlabel('Arrival Time',fontsize=8)
plt.ylabel('Average Price',fontsize=8)
plt.xticks(fontsize=8)
plt.show()
# Out:
# /var/folders/q5/bwsxp4bx3jvb0n9scz0gsk500000gn/T/ipykernel_3282/1720923942.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='arrival_time', y='price', data=arrival_price_summary, palette='viridis')

# %%
# How the price changes with change in Source city and Destination city? 
plt.figure(figsize=(24,10))
plt.subplot(1,2,1)
sns.boxplot(x='source_city',y='price',data=df, palette='viridis')
plt.title('Source City Vs Ticket Price',fontsize=20)
plt.xlabel('Source City',fontsize=15)
plt.ylabel('Price',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.subplot(1,2,2)
sns.boxplot(x='destination_city',y='price',data=df, palette='viridis')
plt.title('Destination City Vs Ticket Price',fontsize=20)
plt.xlabel('Destination City',fontsize=15)
plt.ylabel('Price',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()
# Out:
# /var/folders/q5/bwsxp4bx3jvb0n9scz0gsk500000gn/T/ipykernel_3282/2281441830.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='source_city',y='price',data=df, palette='viridis')
# /var/folders/q5/bwsxp4bx3jvb0n9scz0gsk500000gn/T/ipykernel_3282/2281441830.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='destination_city',y='price',data=df, palette='viridis')

# %%
duration_minute=df['duration']*60
duration_minute
# Out:
# 0          150.0
# 1          435.0
# 2         1140.0
# 3          315.0
# 4          267.0
#            ...
# 311899     604.8
# 311900     625.2
# 311901     829.8
# 311902     600.0
# 311903     604.8
# Name: duration, Length: 311904, dtype: float64

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df['duration'], df['price'], alpha=0.5, color='blue',s=1)

# Add titles and labels
plt.title('Flight Duration vs. Ticket Price', fontsize=16)
plt.xlabel('Duration (Hours)', fontsize=14)
plt.ylabel('Price', fontsize=14)
plt.grid(True)

# Show the plot
plt.show()
